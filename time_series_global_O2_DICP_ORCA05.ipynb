# %%
# %matplotlib inline

import xarray as xr
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
from matplotlib import axes
import numpy as np
import cartopy

import warnings
warnings.simplefilter('ignore')

# %%
# !pwd
# Out:
# /scratch/usr/shkifmmp/notebooks/shared-notebooks

# %% [markdown]
# #### Define paths to data

# %%
# path_05_cy1='/scratch/usr/shklvn09/OLD_WORK1/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1/OUT/yearly/'
# path_05_cy2='/scratch/usr/shklvn09/OLD_WORK1/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle2/OUT/yearly/'
# path_05_cy3='/scratch/usr/shklvn09/OLD_WORK1/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle3/OUT/yearly/'
# path_05_cy4='/scratch/usr/shklvn09/OLD_WORK1/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle4/OUT/yearly/'
# path_05_cy5='/scratch/usr/shklvn09/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP002-cycle5/OUT/yearly/'

# path_05_cy1_new='/scratch/usr/shklvn09/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.LP10-KLP001-cycle1/OUT/'
# path_05_cy2_new='/scratch/usr/shklvn09/SCRATCH/ORCA05.L46.LIM2vp.CFCSF6.MOPS.LP10-KLP001-cycle2/OUT/'
path_test = '/scratch/usr/shkifmmp/notebooks/shared-notebooks/'

# %%
o2_05_cy1
# Out:
# <xarray.DataArray 'O2' (time_counter: 61, deptht: 46, y: 511, x: 722)>
# dask.array<concatenate, shape=(61, 46, 511, 722), dtype=float32, chunksize=(1, 46, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#     nav_lat        (y, x) float32 dask.array<chunksize=(100, 100), meta=np.ndarray>
#     nav_lon        (y, x) float32 dask.array<chunksize=(100, 100), meta=np.ndarray>
#   * deptht         (deptht) float32 3.047 9.454 16.36 ... 5.625e+03 5.875e+03
#     time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#   * time_counter   (time_counter) datetime64[ns] 1958-07-01T17:00:00 ... 2018...
# Dimensions without coordinates: y, x
# Attributes:
#     long_name:           oxygen
#     units:               mmol/m3
#     online_operation:    average
#     interval_operation:  2160 s
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 2160 s) time_counter: mean

# %% [markdown]
# #### O2

# %%
o2_05_cy1 = xr.open_mfdataset(paths = sorted(glob(path_05_cy1 + 'OR*_O2.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# o2_05_cy2 = xr.open_mfdataset(paths = sorted(glob(path_05_cy2 + 'OR*_O2.nc')), concat_dim = 'time_counter',
#                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# o2_05_cy3 = xr.open_mfdataset(paths = sorted(glob(path_05_cy3 + 'OR*_O2.nc')), concat_dim = 'time_counter', 
#                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# o2_05_cy4 = xr.open_mfdataset(paths = sorted(glob(path_05_cy4 + 'OR*_O2.nc')), concat_dim = 'time_counter',                       
#                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# o2_05_cy5 = xr.open_mfdataset(paths = sorted(glob(path_05_cy5 + 'OR*_O2.nc')), concat_dim = 'time_counter', 
#                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2



# o2_05_cy1_new = xr.open_mfdataset(paths = sorted(glob(path_05_cy1_new + 'OR*1y*mops*.nc')), concat_dim = 'time_counter', 
#                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# o2_05_cy2_new = xr.open_mfdataset(paths = sorted(glob(path_05_cy2_new + 'OR*1y*mops*.nc')), concat_dim = 'time_counter', 
#                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-2be76fb250e3> in <module>
#       3 # o2_05_cy2 = xr.open_mfdataset(paths = sorted(glob(path_05_cy2 + 'OR*_O2.nc')), concat_dim = 'time_counter',
#       4 #                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
# ----> 5 o2_05_cy3 = xr.open_mfdataset(paths = sorted(glob(path_05_cy3 + 'OR*_O2.nc')), concat_dim = 'time_counter',
#       6                                   chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).O2
#       7 # o2_05_cy4 = xr.open_mfdataset(paths = sorted(glob(path_05_cy4 + 'OR*_O2.nc')), concat_dim = 'time_counter',
#
# ...

# %% [markdown]
# #### DICP

# %%
dicp_05_cy1 = xr.open_mfdataset(paths = sorted(glob(path_05_cy1 + 'OR*_DICP.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP
dicp_05_cy2 = xr.open_mfdataset(paths = sorted(glob(path_05_cy2 + 'OR*_DICP.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP
dicp_05_cy3 = xr.open_mfdataset(paths = sorted(glob(path_05_cy3 + 'OR*_DICP.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP
dicp_05_cy4 = xr.open_mfdataset(paths = sorted(glob(path_05_cy4 + 'OR*_DICP.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP
dicp_05_cy5 = xr.open_mfdataset(paths = sorted(glob(path_05_cy5 + 'OR*_DICP.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP

dicp_05_cy1_new = xr.open_mfdataset(paths = sorted(glob(path_05_cy1_new + 'OR*1y*mops*.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP
dicp_05_cy2_new = xr.open_mfdataset(paths = sorted(glob(path_05_cy2_new + 'OR*1y*mops*.nc')), concat_dim = 'time_counter', 
                                  chunks={"time_counter":1, "y":100, "x":100, "deptht":46}).DICP

# %%
o2_05_cy1_new.shape
# Out:
# (61, 46, 511, 722)

# %% [markdown]
# #### mask

# %%
maskdir = '/scratch/usr/shklvn09/NUDATA/ORCA/05-data/meshmask/mesh_mask.nc'
tmask_05 = xr.open_dataset(maskdir,
                      chunks={"z":46, "y":100, "x":100}).tmask.squeeze()
e1t_05 = xr.open_dataset(maskdir,
                      chunks={"z":46, "y":100, "x":100}).e1t.squeeze()
e2t_05 = xr.open_dataset(maskdir,
                      chunks={"z":46, "y":100, "x":100}).e2t.squeeze()
e3t_05 = xr.open_dataset(maskdir,
                      chunks={"z":46, "y":100, "x":100}).e3t_0.squeeze()

# %%
tmask_05, e3t_05 = tmask_05.rename({'z':'deptht'}), e3t_05.rename({'z':'deptht'}) #renaming it for mask and tracers to have same dimension name

# %%
tmask_05
# Out:
# <xarray.DataArray 'tmask' (deptht: 46, y: 511, x: 722)>
# dask.array<getitem, shape=(46, 511, 722), dtype=int8, chunksize=(46, 100, 100), chunktype=numpy.ndarray>
# Dimensions without coordinates: deptht, y, x

# %% [markdown]
# #### Compute global integrals and concatenate

# %%
#vol_05=(e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')).squeeze() 
# o2_05_cy1_int = (o2_05_cy1.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')) 
# o2_05_cy2_int = (o2_05_cy2.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
# o2_05_cy3_int = (o2_05_cy3.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
# o2_05_cy4_int = (o2_05_cy4.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
# o2_05_cy5_int = (o2_05_cy5.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')) 

# #o2_05_cy1_int_load = xr.load_dataset(path_05_cy1 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1_global_O2_integral.nc')
# #o2_05_cy2_int = xr.open_dataset(path_05_cy2 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle2_global_O2_integral.nc')
# #o2_05_cy3_int = xr.open_dataset(path_05_cy3 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle3_global_O2_integral.nc')
# #o2_05_cy4_int = xr.open_dataset(path_05_cy4 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle4_global_O2_integral.nc')
# #o2_05_cy5_int = xr.open_dataset(path_05_cy5 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle5_global_O2_integral.nc')


# o2_05_int=np.hstack((np.array(o2_05_cy1_int.values).squeeze(), 
#                        np.array(o2_05_cy2_int.values).squeeze(),
#                        np.array(o2_05_cy3_int.values).squeeze(),
#                        np.array(o2_05_cy4_int.values).squeeze(),
#                        np.array(o2_05_cy5_int.values).squeeze()))

# #o2_05_ave=o2_05_int/np.array(vol_05)

#testing 
o2_05_int=np.hstack((np.array(o2_05_cy1_int.values).squeeze(), 
                       np.array(o2_05_cy1_int.values).squeeze()))

# %%
o2_05_int
# Out:
# array([<bound method Mapping.values of <xarray.Dataset>
#        Dimensions:        (time_counter: 61)
#        Coordinates:
#            time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#          * time_counter   (time_counter) datetime64[ns] 1958-07-01T17:00:00 ... 2018...
#        Data variables:
#            o2_integral    (time_counter) float64 dask.array<chunksize=(1,), meta=np.ndarray>>      ,
#        <bound method Mapping.values of <xarray.Dataset>
#        Dimensions:        (time_counter: 61)
#        Coordinates:
#            time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#          * time_counter   (time_counter) datetime64[ns] 1958-07-01T17:00:00 ... 2018...
#        Data variables:
#            o2_integral    (time_counter) float64 dask.array<chunksize=(1,), meta=np.ndarray>>      ],
#       dtype=object)

# %%
# Store the integrated fields on disk 
o2_05_cy1_int = o2_05_cy1_int.to_dataset(name='o2_integral')
o2_05_cy1_int.to_netcdf(path_test + 'ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1_global_O2_integral.nc', mode='w')
#o2_05_cy2_int.to_netcdf(path_05_cy2 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle2_global_O2_integral.nc', mode='w')
#o2_05_cy3_int.to_netcdf(path_05_cy3 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle3_global_O2_integral.nc', mode='w')
#o2_05_cy4_int.to_netcdf(path_05_cy4 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle4_global_O2_integral.nc', mode='w')
#o2_05_cy5_int.to_netcdf(path_05_cy5 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle5_global_O2_integral.nc', mode='w')

# %%
o2_05_cy1_int_load = xr.load_dataset(path_05_cy1 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1_global_O2_integral.nc')

# %%
pippo=o2_05_cy1_int_load.__xarray_dataarray_variable__

# %%
pippo.shape
# Out:
# (61,)

# %%
dicp_05_cy1_int = (dicp_05_cy1.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')) 
dicp_05_cy2_int = (dicp_05_cy2.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
dicp_05_cy3_int = (dicp_05_cy3.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
dicp_05_cy4_int = (dicp_05_cy4.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))
dicp_05_cy5_int = (dicp_05_cy5.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')) 

#dicp_05_cy1_int = xr.open_dataset(path_05_cy1 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1_global_dicp_integral.nc')
#dicp_05_cy2_int = xr.open_dataset(path_05_cy2 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle2_global_dicp_integral.nc')
#dicp_05_cy3_int = xr.open_dataset(path_05_cy3 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle3_global_dicp_integral.nc')
#dicp_05_cy4_int = xr.open_dataset(path_05_cy4 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle4_global_dicp_integral.nc')
#dicp_05_cy5_int = xr.open_dataset(path_05_cy5 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle5_global_dicp_integral.nc')



dicp_05_int=np.hstack((np.array(dicp_05_cy1_int.values).squeeze(), 
                       np.array(dicp_05_cy2_int.values).squeeze(),
                       np.array(dicp_05_cy3_int.values).squeeze(),
                       np.array(dicp_05_cy4_int.values).squeeze(),
                       np.array(dicp_05_cy5_int.values).squeeze()))

# %%
# Store the integrated fields on disk 
#dicp_05_cy1_int.to_netcdf(path_05_cy1 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle1_global_dicp_integral.nc', mode='w')
#dicp_05_cy2_int.to_netcdf(path_05_cy2 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle2_global_dicp_integral.nc', mode='w')
#dicp_05_cy3_int.to_netcdf(path_05_cy3 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle3_global_dicp_integral.nc', mode='w')
#dicp_05_cy4_int.to_netcdf(path_05_cy4 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle4_global_dicp_integral.nc', mode='w')
#dicp_05_cy5_int.to_netcdf(path_05_cy5 + 'integrals/ORCA05.L46.LIM2vp.CFCSF6.MOPS.B.LP09-KLP001-cycle5_global_dicp_integral.nc', mode='w')

# %%
dicp_05_cy1_int_new = (dicp_05_cy1_new.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht')) 
o2_05_cy1_int_new = (o2_05_cy1_new.where(tmask_05) * e1t_05 * e2t_05 * e3t_05).sum(('x','y','deptht'))

# %%
dicp_05_cy1_new.shape

# %% [markdown]
# #### Plotting O2

# %%
plt.figure(figsize=(12,7))
ax = plt.gca()
ax.plot(np.arange(0, 297),o2_05_int, color='black', linewidth=2, label='LP09')
ax.plot(np.arange(0, 61),o2_05_cy1_int_new, color='red', linewidth=2, label='LP10')


ax.set_ylabel("mmol", fontsize = 16)
ax.set_title("Global O2 inventory", fontsize = 18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
axes.Axes.tick_params(ax, axis='both' ,labelsize=14)
ax.grid()
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., fontsize=12)


locs, labels = plt.xticks()
plt.xticks(np.arange(0, 305, step=61), ('cycle01', 'cycle02', 'cycle03', 'cycle04', 'cycle05'), rotation=25)

plt.tight_layout()

#savepath = '/scratch/usr/shklvn09/notebooks/shared-notebooks/figures/Paper_CO2/'
#plt.savefig(savepath + 'DICP_glob_inv_ORCA05_ORCA025_ORION10.png', format='png', facecolor="w")

# %% [markdown]
# #### Plotting DICP

# %%
plt.figure(figsize=(12,7))
ax = plt.gca()
ax.plot(np.arange(0, 305),dicp_05_int, color='black', linewidth=2, label='LP09')
ax.plot(np.arange(0, 61),dicp_05_cy1_int_new, color='red', linewidth=2, label='LP10')


ax.set_ylabel("mol", fontsize = 16)
ax.set_title("Global DICP inventory", fontsize = 18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
axes.Axes.tick_params(ax, axis='both' ,labelsize=14)
ax.grid()
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., fontsize=12)


locs, labels = plt.xticks()
plt.xticks(np.arange(0, 305, step=61), ('cycle01', 'cycle02', 'cycle03', 'cycle04', 'cycle05'), rotation=25)

plt.tight_layout()

#savepath = '/scratch/usr/shklvn09/notebooks/shared-notebooks/figures/Paper_CO2/'
#plt.savefig(savepath + 'DICP_glob_inv_ORCA05_ORCA025_ORION10.png', format='png', facecolor="w")
